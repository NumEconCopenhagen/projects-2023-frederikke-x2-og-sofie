# %% [markdown]
# # Data project

# %% [markdown]
# This project examine the level of education and the unemployment rate. It will be analysed wether there are a connection between the level of education and the unemployment rate. The level of education is based on the highest completed education. The project is based on data from the danish population in the years from 2008 to 2022.

# %%
#Installing the DST API wrapper
# %pip install git+https://github.com/alemartinello/dstapi
# Istalling a wrapper for multiple APIs with a pandas interface
# %pip install pandas-datareader
# Out:
# Collecting git+https://github.com/alemartinello/dstapi
#   Cloning https://github.com/alemartinello/dstapi to /private/var/folders/4z/wf9qts311_l6__4y75rztx8c0000gn/T/pip-req-build-are__xrc
#   Running command git clone --filter=blob:none --quiet https://github.com/alemartinello/dstapi /private/var/folders/4z/wf9qts311_l6__4y75rztx8c0000gn/T/pip-req-build-are__xrc
#   Resolved https://github.com/alemartinello/dstapi to commit d9eeb5a82cbc70b7d63b2ff44d92632fd77123a4
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from dstapi==0.2) (1.4.4)
# Requirement already satisfied: requests in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from dstapi==0.2) (2.28.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from pandas->dstapi==0.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from pandas->dstapi==0.2) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from pandas->dstapi==0.2) (1.21.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from requests->dstapi==0.2) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from requests->dstapi==0.2) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from requests->dstapi==0.2) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from requests->dstapi==0.2) (3.3)
# Requirement already satisfied: six>=1.5 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->dstapi==0.2) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas-datareader in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (0.10.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from pandas-datareader) (2.28.1)
# Requirement already satisfied: pandas>=0.23 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from pandas-datareader) (1.4.4)
# Requirement already satisfied: lxml in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from pandas-datareader) (4.9.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->pandas-datareader) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->pandas-datareader) (1.21.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas-datareader) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas-datareader) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas-datareader) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas-datareader) (2.0.4)
# Requirement already satisfied: six>=1.5 in /Users/frederikkelund/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas-datareader) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Imports and set magics:

# %%
import numpy as np
import pandas as pd
import datetime
import ipywidgets as widgets
from scipy.stats import norm

import pandas_datareader # install with `pip install pandas-datareader`
from dstapi import DstApi # install with `pip install git+https://github.com/alemartinello/dstapi`
# %matplotlib inline
import matplotlib.pyplot as plt

import dataproject1 as dp

#We set the following parameter globaly for the project: the gridlines, its colour to black, Sets its transparency and its style to --
plt.rcParams.update({"axes.grid":True,"grid.color":"black","grid.alpha":"0.25","grid.linestyle":"--"})
plt.rcParams.update({'font.size': 14}) #here the font size is set to 14.

# %% [markdown]
# # Read and clean data

# %% [markdown]
# We use data about the population's highest completed education. The data is divided by age, area of ​​residence, origin, highest completed education and gender

# %%
# Importing the data from DST 
ind = DstApi('HFUDD11')

# %%
# Printing a overview of the data
ind_tabel = ind.tablesummary(language='en')
display(ind_tabel)
# Out:
# Table HFUDD11: Educational attainment (15-69 years) by region, ancestry, highest education completed, age, sex and time
# Last update: 2023-03-30T08:00:00
#   variable name  # values First value First value label Last value  \
# 0        BOPOMR       105         000       All Denmark        851
# 1      HERKOMST         4         TOT             Total          3
# 2         HFUDD        93         TOT             Total      H9099
# 3         ALDER        12         TOT        Age, total      65-69
# 4           KØN         3         TOT             Total          K
# 5           Tid        15        2008              2008       2022
#
#    Last value label  Time variable
# 0           Aalborg          False
# 1        Descendant          False
# 2  H9099 Not stated          False
# 3       65-69 years          False
# 4             Women          False
# 5              2022           True

# %%
# The available values for each variable is displayed: 
for variable in ind_tabel['variable name']:
    print(variable+':')
    display(ind.variable_levels(variable, language='en'))
# Out:
# BOPOMR:
#       id                text
# 0    000         All Denmark
# 1    084  Region Hovedstaden
# 2    101          Copenhagen
# 3    147       Frederiksberg
# 4    155              Dragør
# ..   ...                 ...
# 100  773               Morsø
# 101  840              Rebild
# 102  787             Thisted
# 103  820     Vesthimmerlands
# 104  851             Aalborg
#
# [105 rows x 2 columns]
# HERKOMST:
#     id                      text
# 0  TOT                     Total
# 1    5  Persons of Danish origin
# 2    4                Immigrants
# 3    3                Descendant
# HFUDD:
#        id                                       text
# 0     TOT                                      Total
# 1     H10                      H10 Primary education
# 2   H1001                         H1001 No education
# 3   H1010  H1010 Primary school through to 6th grade
# 4   H1020         H1020 Primary school 7th-9th grade
# ..    ...                                        ...
# 88  H8080                       H8080 PhD programmes
# 89  H8090                  H8090 Health science, PhD
# 90  H8097  H8097 Higher education not specified, PhD
# 91    H90                             H90 Not stated
# 92  H9099                           H9099 Not stated
#
# [93 rows x 2 columns]
# ALDER:
#        id         text
# 0     TOT   Age, total
# 1   15-19  15-19 years
# 2   20-24  20-24 years
# 3   25-29  25-29 years
# 4   30-34  30-34 years
# 5   35-39  35-39 years
# 6   40-44  40-44 years
# 7   45-49  45-49 years
# 8   50-54  50-54 years
# 9   55-59  55-59 years
# 10  60-64  60-64 years
# 11  65-69  65-69 years
# KØN:
#     id   text
# 0  TOT  Total
# 1    M    Men
# 2    K  Women
# Tid:
#       id  text
# 0   2008  2008
# 1   2009  2009
# 2   2010  2010
# 3   2011  2011
# 4   2012  2012
# 5   2013  2013
# 6   2014  2014
# 7   2015  2015
# 8   2016  2016
# 9   2017  2017
# 10  2018  2018
# 11  2019  2019
# 12  2020  2020
# 13  2021  2021
# 14  2022  2022

# %%
# The parameters are selected
params_ind = {'table': 'hfudd11',
 'format': 'BULK',
 'lang': 'en',
 'variables': [{'code': 'BOPOMR', 'values': ['000']},
  {'code': 'HERKOMST', 'values': ['TOT']},
  {'code': 'HFUDD', 'values': ['H40','H50', 'H70']},
  {'code': 'ALDER', 'values': ['35-39']},
  {'code': 'KØN', 'values': ['M','K']},
  {'code': 'Tid', 'values': ['>2017<=2021']}]}

# %%
#The parameters are made into a tabel
ind_tabel = ind.get_data(params=params_ind)
ind_tabel.head(10)
# Out:
#         BOPOMR HERKOMST                                HFUDD        ALDER  \
# 0  All Denmark    Total     H40 Short cycle higher education  35-39 years
# 1  All Denmark    Total     H40 Short cycle higher education  35-39 years
# 2  All Denmark    Total  H50 Vocational bachelors educations  35-39 years
# 3  All Denmark    Total  H50 Vocational bachelors educations  35-39 years
# 4  All Denmark    Total                 H70 Masters programs  35-39 years
# 5  All Denmark    Total                 H70 Masters programs  35-39 years
# 6  All Denmark    Total     H40 Short cycle higher education  35-39 years
# 7  All Denmark    Total     H40 Short cycle higher education  35-39 years
# 8  All Denmark    Total  H50 Vocational bachelors educations  35-39 years
# 9  All Denmark    Total  H50 Vocational bachelors educations  35-39 years
#
#      KØN   TID  INDHOLD
# 0  Women  2018     9573
# 1    Men  2018    11546
# 2  Women  2018    41903
# 3    Men  2018    21943
# 4  Women  2018    31463
# 5    Men  2018    27214
# 6  Women  2019     9281
# 7    Men  2019    11101
# 8  Women  2019    41552
# 9    Men  2019    22614

# %%
#Columnames are changed
rename_dict = {'BOPOMR':'AREA', 'HERKOMST':'ETHNICITY', 'HFUDD':'EDUCATION LEVEL', 'ALDER':'AGE', 'KØN':'SEX', 'TID':'YEAR', 'INDHOLD':'EDUCATED'}

ind_tabel.rename(columns=rename_dict, inplace=True)
ind_tabel.head(10)
# Out:
#           AREA ETHNICITY                      EDUCATION LEVEL          AGE  \
# 0  All Denmark     Total     H40 Short cycle higher education  35-39 years
# 1  All Denmark     Total     H40 Short cycle higher education  35-39 years
# 2  All Denmark     Total  H50 Vocational bachelors educations  35-39 years
# 3  All Denmark     Total  H50 Vocational bachelors educations  35-39 years
# 4  All Denmark     Total                 H70 Masters programs  35-39 years
# 5  All Denmark     Total                 H70 Masters programs  35-39 years
# 6  All Denmark     Total     H40 Short cycle higher education  35-39 years
# 7  All Denmark     Total     H40 Short cycle higher education  35-39 years
# 8  All Denmark     Total  H50 Vocational bachelors educations  35-39 years
# 9  All Denmark     Total  H50 Vocational bachelors educations  35-39 years
#
#      SEX  YEAR  EDUCATED
# 0  Women  2018      9573
# 1    Men  2018     11546
# 2  Women  2018     41903
# 3    Men  2018     21943
# 4  Women  2018     31463
# 5    Men  2018     27214
# 6  Women  2019      9281
# 7    Men  2019     11101
# 8  Women  2019     41552
# 9    Men  2019     22614

# %%
#Specific variables are dropped
ind_tabel2 = ind_tabel.drop(columns=  ["AREA", "ETHNICITY", "AGE"])
ind_tabel2
# Out:
#                         EDUCATION LEVEL    SEX  YEAR  EDUCATED
# 0      H40 Short cycle higher education  Women  2018      9573
# 1      H40 Short cycle higher education    Men  2018     11546
# 2   H50 Vocational bachelors educations  Women  2018     41903
# 3   H50 Vocational bachelors educations    Men  2018     21943
# 4                  H70 Masters programs  Women  2018     31463
# 5                  H70 Masters programs    Men  2018     27214
# 6      H40 Short cycle higher education  Women  2019      9281
# 7      H40 Short cycle higher education    Men  2019     11101
# 8   H50 Vocational bachelors educations  Women  2019     41552
# 9   H50 Vocational bachelors educations    Men  2019     22614
# 10                 H70 Masters programs  Women  2019     32964
# 11                 H70 Masters programs    Men  2019     27857
# 12     H40 Short cycle higher education  Women  2020      9129
# 13     H40 Short cycle higher education    Men  2020     10920
# 14  H50 Vocational bachelors educations  Women  2020     41729
# 15  H50 Vocational bachelors educations    Men  2020     23433
# 16                 H70 Masters programs  Women  2020     34186
# 17                 H70 Masters programs    Men  2020     28107
# 18     H40 Short cycle higher education  Women  2021      9148
# 19     H40 Short cycle higher education    Men  2021     11190
# 20  H50 Vocational bachelors educations  Women  2021     42664
# 21  H50 Vocational bachelors educations    Men  2021     24939
# 22                 H70 Masters programs  Women  2021     36036
# 23                 H70 Masters programs    Men  2021     29317

# %%
#The tabel is split into to two, one tabel for men one for women
ind_tabel2_men = ind_tabel2[ind_tabel2["SEX"] == "Men"]
ind_tabel2_men

ind_tabel2_women = ind_tabel2[ind_tabel2["SEX"] == "Women"]
ind_tabel2_women
# Out:
#                         EDUCATION LEVEL    SEX  YEAR  EDUCATED
# 0      H40 Short cycle higher education  Women  2018      9573
# 2   H50 Vocational bachelors educations  Women  2018     41903
# 4                  H70 Masters programs  Women  2018     31463
# 6      H40 Short cycle higher education  Women  2019      9281
# 8   H50 Vocational bachelors educations  Women  2019     41552
# 10                 H70 Masters programs  Women  2019     32964
# 12     H40 Short cycle higher education  Women  2020      9129
# 14  H50 Vocational bachelors educations  Women  2020     41729
# 16                 H70 Masters programs  Women  2020     34186
# 18     H40 Short cycle higher education  Women  2021      9148
# 20  H50 Vocational bachelors educations  Women  2021     42664
# 22                 H70 Masters programs  Women  2021     36036

# %%
#importing dataset 2
unemp = DstApi('KAS209')
# Printing a overview of the data
tabsum_unemp = unemp.tablesummary(language='en')
display(tabsum_unemp)
# The available values for a each variable: 
for variable in tabsum_unemp['variable name']:
    print(variable+':')
    display(unemp.variable_levels(variable, language='en'))
# Out:
# Table KAS209: Population by region, education, socioeconomic status, age, sex, period and time
# Last update: 2023-03-03T08:00:00
#   variable name  # values First value First value label Last value  \
# 0        OMRÅDE       116         000       All Denmark        851
# 1    UDDANNELSE        11         TOT             Total        H90
# 2         SOCIO        34         TOT             Total        175
# 3         ALDER        13         -15    Under 16 years        67-
# 4           KØN         3         TOT             Total          K
# 5       PERIODE         5           1        Whole year         K4
# 6           Tid         5        2017              2017       2021
#
#                   Last value label  Time variable
# 0                          Aalborg          False
# 1                   H90 Not stated          False
# 2  Others outside the labour force          False
# 3                67 years and over          False
# 4                            Women          False
# 5                       4. quarter          False
# 6                             2021           True
# OMRÅDE:
#       id                     text
# 0    000              All Denmark
# 1    084       Region Hovedstaden
# 2     01  Province Byen København
# 3    101               Copenhagen
# 4    147            Frederiksberg
# ..   ...                      ...
# 111  773                    Morsø
# 112  840                   Rebild
# 113  787                  Thisted
# 114  820          Vesthimmerlands
# 115  851                  Aalborg
#
# [116 rows x 2 columns]
# UDDANNELSE:
#      id                                         text
# 0   TOT                                        Total
# 1   H10                        H10 Primary education
# 2   H20                H20 Upper secondary education
# 3   H30  H30 Vocational Education and Training (VET)
# 4   H35          H35 Qualifying educational programs
# 5   H40             H40 Short cycle higher education
# 6   H50          H50 Vocational bachelors educations
# 7   H60                       H60 Bachelors programs
# 8   H70                         H70 Masters programs
# 9   H80                             H80 PhD programs
# 10  H90                               H90 Not stated
# SOCIO:
#      id                                               text
# 0   TOT                                              Total
# 1    05                                      Self-employed
# 2    10                                  Assisting spouses
# 3    15                                Employees, managers
# 4    20                            Employees - upper level
# 5    25                           Employees - medium level
# 6    30                            Employees - basic level
# 7    35                                    Other employees
# 8    40                           Employees, not specified
# 9    50                                         Unemployed
# 10   80               Subsidized employment without salary
# 11   85                 Persons receiving holiday benefits
# 12   90           Guidance and activities upgrading skills
# 13   95                               Unemployment benefit
# 14  100                   Parental leave from unemployment
# 15  105                Maternity absence from unemployment
# 16  110                 Sickness absence from unemployment
# 17  115  Cash benefit (passive)/cash benefit for foreig...
# 18  120                                     Rehabilitation
# 19  125                          Specially arranged scheme
# 20  128                          Job clarification program
# 21  130  Danish State Education Grant and Loan Scheme A...
# 22  135                                 Disability pension
# 23  138                                      Seniorpension
# 24  140                               Early retirement pay
# 25  145                                       Flex benefit
# 26  150                                    Old-age pension
# 27  155                                     Other pensions
# 28  154                   Enrolled in education (ordinary)
# 29  156                                Course participants
# 30  158                     Students at production schools
# 31  160                                   Foreign students
# 32  170     Children and youth (not enrolled in education)
# 33  175                    Others outside the labour force
# ALDER:
#        id               text
# 0     -15     Under 16 years
# 1   16-19        16-19 years
# 2   20-24        20-24 years
# 3   25-29        25-29 years
# 4   30-34        30-34 years
# 5   35-39        35-39 years
# 6   40-44        40-44 years
# 7   45-49        45-49 years
# 8   50-54        50-54 years
# 9   55-59        55-59 years
# 10  60-64        60-64 years
# 11  65-66        65-66 years
# 12    67-  67 years and over
# KØN:
#     id   text
# 0  TOT  Total
# 1    M    Men
# 2    K  Women
# PERIODE:
#    id        text
# 0   1  Whole year
# 1  K1  1. quarter
# 2  K2  2. quarter
# 3  K3  3. quarter
# 4  K4  4. quarter
# Tid:
#      id  text
# 0  2017  2017
# 1  2018  2018
# 2  2019  2019
# 3  2020  2020
# 4  2021  2021

# %%
# Variables form the data is selected
params_unemp = {'table': 'KAS209',
 'format': 'BULK',
 'lang': 'en',
 'variables': [{'code': 'OMRÅDE', 'values': ['000']},
  {'code': 'UDDANNELSE', 'values': ['H40','H50', 'H70']},
  {'code': 'SOCIO', 'values': ['50']},
  {'code': 'ALDER', 'values': ['35-39']},
  {'code': 'KØN', 'values': ['M','K']},
  {'code': 'PERIODE', 'values': ['1']},
  {'code': 'Tid', 'values': ['>2017<=2021']}]}

# %%
#The variables are made into a table
unemp_tabel = unemp.get_data(params=params_unemp)
unemp_tabel.head(10)
# Out:
#         OMRÅDE                           UDDANNELSE       SOCIO        ALDER  \
# 0  All Denmark     H40 Short cycle higher education  Unemployed  35-39 years
# 1  All Denmark     H40 Short cycle higher education  Unemployed  35-39 years
# 2  All Denmark  H50 Vocational bachelors educations  Unemployed  35-39 years
# 3  All Denmark  H50 Vocational bachelors educations  Unemployed  35-39 years
# 4  All Denmark                 H70 Masters programs  Unemployed  35-39 years
# 5  All Denmark                 H70 Masters programs  Unemployed  35-39 years
# 6  All Denmark     H40 Short cycle higher education  Unemployed  35-39 years
# 7  All Denmark     H40 Short cycle higher education  Unemployed  35-39 years
# 8  All Denmark  H50 Vocational bachelors educations  Unemployed  35-39 years
# 9  All Denmark  H50 Vocational bachelors educations  Unemployed  35-39 years
#
#      KØN     PERIODE   TID  INDHOLD
# 0  Women  Whole year  2018      326
# 1    Men  Whole year  2018      253
# 2  Women  Whole year  2018     1063
# 3    Men  Whole year  2018      562
# 4  Women  Whole year  2018     1096
# 5    Men  Whole year  2018      702
# 6  Women  Whole year  2019      340
# 7    Men  Whole year  2019      245
# 8  Women  Whole year  2019     1098
# 9    Men  Whole year  2019      609

# %%
#Columnames are changed
rename_dict2 = {'OMRÅDE':'AREA', 'UDDANNELSE':'EDUCATION LEVEL', 'SOCIO':'STATUS', 'ALDER':'AGE', 'KØN':'SEX', 'TID':'YEAR', 'INDHOLD':'UNEMPLOYED'}

unemp_tabel.rename(columns=rename_dict2, inplace=True)
unemp_tabel.head(10)
# Out:
#           AREA                      EDUCATION LEVEL      STATUS          AGE  \
# 0  All Denmark     H40 Short cycle higher education  Unemployed  35-39 years
# 1  All Denmark     H40 Short cycle higher education  Unemployed  35-39 years
# 2  All Denmark  H50 Vocational bachelors educations  Unemployed  35-39 years
# 3  All Denmark  H50 Vocational bachelors educations  Unemployed  35-39 years
# 4  All Denmark                 H70 Masters programs  Unemployed  35-39 years
# 5  All Denmark                 H70 Masters programs  Unemployed  35-39 years
# 6  All Denmark     H40 Short cycle higher education  Unemployed  35-39 years
# 7  All Denmark     H40 Short cycle higher education  Unemployed  35-39 years
# 8  All Denmark  H50 Vocational bachelors educations  Unemployed  35-39 years
# 9  All Denmark  H50 Vocational bachelors educations  Unemployed  35-39 years
#
#      SEX     PERIODE  YEAR  UNEMPLOYED
# 0  Women  Whole year  2018         326
# 1    Men  Whole year  2018         253
# 2  Women  Whole year  2018        1063
# 3    Men  Whole year  2018         562
# 4  Women  Whole year  2018        1096
# 5    Men  Whole year  2018         702
# 6  Women  Whole year  2019         340
# 7    Men  Whole year  2019         245
# 8  Women  Whole year  2019        1098
# 9    Men  Whole year  2019         609

# %%
#Specific parameters are droped
unemp_tabel2 = unemp_tabel.drop(columns=  ["AREA", "AGE", "PERIODE"])
unemp_tabel2
# Out:
#                         EDUCATION LEVEL      STATUS    SEX  YEAR  UNEMPLOYED
# 0      H40 Short cycle higher education  Unemployed  Women  2018         326
# 1      H40 Short cycle higher education  Unemployed    Men  2018         253
# 2   H50 Vocational bachelors educations  Unemployed  Women  2018        1063
# 3   H50 Vocational bachelors educations  Unemployed    Men  2018         562
# 4                  H70 Masters programs  Unemployed  Women  2018        1096
# 5                  H70 Masters programs  Unemployed    Men  2018         702
# 6      H40 Short cycle higher education  Unemployed  Women  2019         340
# 7      H40 Short cycle higher education  Unemployed    Men  2019         245
# 8   H50 Vocational bachelors educations  Unemployed  Women  2019        1098
# 9   H50 Vocational bachelors educations  Unemployed    Men  2019         609
# 10                 H70 Masters programs  Unemployed  Women  2019        1135
# 11                 H70 Masters programs  Unemployed    Men  2019         714
# 12     H40 Short cycle higher education  Unemployed  Women  2020         433
# 13     H40 Short cycle higher education  Unemployed    Men  2020         351
# 14  H50 Vocational bachelors educations  Unemployed  Women  2020        1428
# 15  H50 Vocational bachelors educations  Unemployed    Men  2020         878
# 16                 H70 Masters programs  Unemployed  Women  2020        1490
# 17                 H70 Masters programs  Unemployed    Men  2020         906
# 18     H40 Short cycle higher education  Unemployed  Women  2021         342
# 19     H40 Short cycle higher education  Unemployed    Men  2021         290
# 20  H50 Vocational bachelors educations  Unemployed  Women  2021        1252
# 21  H50 Vocational bachelors educations  Unemployed    Men  2021         720
# 22                 H70 Masters programs  Unemployed  Women  2021        1310
# 23                 H70 Masters programs  Unemployed    Men  2021         861

# %%
#The tabel is split into to two - again one for men one for women
unemp_tabel2_men = unemp_tabel2[unemp_tabel2["SEX"] == "Men"]
unemp_tabel2_men

unemp_tabel2_women = unemp_tabel2[unemp_tabel2["SEX"] == "Women"]
unemp_tabel2_women
# Out:
#                         EDUCATION LEVEL      STATUS    SEX  YEAR  UNEMPLOYED
# 0      H40 Short cycle higher education  Unemployed  Women  2018         326
# 2   H50 Vocational bachelors educations  Unemployed  Women  2018        1063
# 4                  H70 Masters programs  Unemployed  Women  2018        1096
# 6      H40 Short cycle higher education  Unemployed  Women  2019         340
# 8   H50 Vocational bachelors educations  Unemployed  Women  2019        1098
# 10                 H70 Masters programs  Unemployed  Women  2019        1135
# 12     H40 Short cycle higher education  Unemployed  Women  2020         433
# 14  H50 Vocational bachelors educations  Unemployed  Women  2020        1428
# 16                 H70 Masters programs  Unemployed  Women  2020        1490
# 18     H40 Short cycle higher education  Unemployed  Women  2021         342
# 20  H50 Vocational bachelors educations  Unemployed  Women  2021        1252
# 22                 H70 Masters programs  Unemployed  Women  2021        1310

# %% [markdown]
# ## Explore each data set

# %% [markdown]
# To explore the data sets, plot the four tables to illustrate the development

# %%
#We plot the number of educated men in the years from 2018 to 2021
educations = ['H40 Short cycle higher education','H50 Vocational bachelors educations','H70 Masters programs']

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

# Here we use the fact that the index has multiple levels (years) for an elegant loop
for m in educations: #for loop is started, that iterates over each element m in the educations iterable
   I = (ind_tabel2_men["EDUCATION LEVEL"] == m) #The values in the education level column is compared  with the current education level  for m
   years = unemp_tabel2_men.loc[:, 'YEAR'] #The value in the YEAR column is assing the years variables 
   ind_tabel2_men.loc[I,:].plot(x='YEAR',y='EDUCATED',ax=ax,label=m, xticks=years) #a plotting operation

ax.legend(frameon=True, loc  = 'center left', bbox_to_anchor=(1, 0.5)) #"True" makes sure, that a frame will be drawn, loc determins the posision
#of the legend, the last command defines the position of the legend relative to the plot

#We plot the number of educated women in the years from 2018 to 2021
educations2 = ['H40 Short cycle higher education','H50 Vocational bachelors educations','H70 Masters programs']

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

# Here we use the fact that the index has multiple levels (years) for an elegant loop
for m in educations2:
   I = (ind_tabel2_women["EDUCATION LEVEL"] == m)
   ind_tabel2_women.loc[I,:].plot(x='YEAR',y='EDUCATED',ax=ax,label=m, xticks=years)
   #ind_tabel2_men.xs(m).plot(x='YEAR',y='EDUCATED',ax=ax,label=m)

ax.legend(frameon=True, loc  = 'center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# The two plots illustrated above shows the number of men with a short cycle higher education, a vocational bachelors educations and a masters program the same for women from 2018 to 2021. It is clear from the two plots that more women tend to have a vocational bachelors education, whereas more men tend to have a short cycle education. The amount of men and women with a short cycle education for both men and women is roughly the same over the years, but when combining the educations a lot more women have finished an education than men.

# %%
#We plot the number of unemployed with the three different educations men in the years from 2018 to 2021
unemployment = ['H40 Short cycle higher education','H50 Vocational bachelors educations','H70 Masters programs']

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

# Here we use the fact that the index has multiple levels (years) for an elegant loop
for m in unemployment:
   I = (unemp_tabel2_men["EDUCATION LEVEL"] == m)
   years = unemp_tabel2_men.loc[:, 'YEAR']
   unemp_tabel2_men.loc[I,:].plot(x='YEAR',y='UNEMPLOYED',ax=ax,label=m, xticks=years)


ax.legend(frameon=True, loc  = 'center left', bbox_to_anchor=(1, 0.5))

#We plot the number of educated women in the years from 2018 to 2021
unemployment2 = ['H40 Short cycle higher education','H50 Vocational bachelors educations','H70 Masters programs']

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

# Here we use the fact that the index has multiple levels (years) for an elegant loop
for m in unemployment2:
   I = (unemp_tabel2_women["EDUCATION LEVEL"] == m)
   unemp_tabel2_women.loc[I,:].plot(x='YEAR',y='UNEMPLOYED',ax=ax,label=m, xticks=years)
   #ind_tabel2_men.xs(m).plot(x='YEAR',y='EDUCATED',ax=ax,label=m)

ax.legend(frameon=True, loc  = 'center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# The two plots above show how many are unemployed with either a short cycle education, a vocational bachelors education or a masters program. The first plot whows for men and the second for women. Even though as concluded before that more women have an education the rate of unemployment for women with either one of these eduactions is a bit higher than for men. Around 2020 the numbers of unemployed for both men and women with either one of the educations is rising, this could be due to corona, but this is decilining again towards 2021.

# %% [markdown]
# # Merge data sets

# %% [markdown]
# to furter explore the data, we merge the two data set, so we have one tabel, that countains both the unemployment and number of educated. After we split the tabel into to two. One for men and one for women.
#
# Lastly we make an interactive plot, where men and women can be analyzed on their educational level.

# %%
#To combine the two datasats, we merge the number of unemployed to dataset IND. 
#The new data set, will then contain the both the number og unemployed and educated, for the three educational level on men and women
Merged_data = ind_tabel2.merge(unemp_tabel2, on=['EDUCATION LEVEL', 'SEX', 'YEAR'], how='left') #define which variables are the same in each
#dataset, so it wont come out twice.
Merged_data #Illustate the new data
# Out:
#                         EDUCATION LEVEL    SEX  YEAR  EDUCATED      STATUS  \
# 0      H40 Short cycle higher education  Women  2018      9573  Unemployed
# 1      H40 Short cycle higher education    Men  2018     11546  Unemployed
# 2   H50 Vocational bachelors educations  Women  2018     41903  Unemployed
# 3   H50 Vocational bachelors educations    Men  2018     21943  Unemployed
# 4                  H70 Masters programs  Women  2018     31463  Unemployed
# 5                  H70 Masters programs    Men  2018     27214  Unemployed
# 6      H40 Short cycle higher education  Women  2019      9281  Unemployed
# 7      H40 Short cycle higher education    Men  2019     11101  Unemployed
# 8   H50 Vocational bachelors educations  Women  2019     41552  Unemployed
# 9   H50 Vocational bachelors educations    Men  2019     22614  Unemployed
# 10                 H70 Masters programs  Women  2019     32964  Unemployed
# 11                 H70 Masters programs    Men  2019     27857  Unemployed
# 12     H40 Short cycle higher education  Women  2020      9129  Unemployed
# 13     H40 Short cycle higher education    Men  2020     10920  Unemployed
# 14  H50 Vocational bachelors educations  Women  2020     41729  Unemployed
# 15  H50 Vocational bachelors educations    Men  2020     23433  Unemployed
# 16                 H70 Masters programs  Women  2020     34186  Unemployed
# 17                 H70 Masters programs    Men  2020     28107  Unemployed
# 18     H40 Short cycle higher education  Women  2021      9148  Unemployed
# 19     H40 Short cycle higher education    Men  2021     11190  Unemployed
# 20  H50 Vocational bachelors educations  Women  2021     42664  Unemployed
# 21  H50 Vocational bachelors educations    Men  2021     24939  Unemployed
# 22                 H70 Masters programs  Women  2021     36036  Unemployed
# 23                 H70 Masters programs    Men  2021     29317  Unemployed
#
#     UNEMPLOYED
# 0          326
# 1          253
# 2         1063
# 3          562
# 4         1096
# 5          702
# 6          340
# 7          245
# 8         1098
# 9          609
# 10        1135
# 11         714
# 12         433
# 13         351
# 14        1428
# 15         878
# 16        1490
# 17         906
# 18         342
# 19         290
# 20        1252
# 21         720
# 22        1310
# 23         861

# %%
#To be able to make an interactive graph, the data is split into men and women.
#The merged data for men is made first
Merged_data_men = Merged_data[Merged_data["SEX"]=="Men"]
Merged_data_men
# Out:
#                         EDUCATION LEVEL  SEX  YEAR  EDUCATED      STATUS  \
# 1      H40 Short cycle higher education  Men  2018     11546  Unemployed
# 3   H50 Vocational bachelors educations  Men  2018     21943  Unemployed
# 5                  H70 Masters programs  Men  2018     27214  Unemployed
# 7      H40 Short cycle higher education  Men  2019     11101  Unemployed
# 9   H50 Vocational bachelors educations  Men  2019     22614  Unemployed
# 11                 H70 Masters programs  Men  2019     27857  Unemployed
# 13     H40 Short cycle higher education  Men  2020     10920  Unemployed
# 15  H50 Vocational bachelors educations  Men  2020     23433  Unemployed
# 17                 H70 Masters programs  Men  2020     28107  Unemployed
# 19     H40 Short cycle higher education  Men  2021     11190  Unemployed
# 21  H50 Vocational bachelors educations  Men  2021     24939  Unemployed
# 23                 H70 Masters programs  Men  2021     29317  Unemployed
#
#     UNEMPLOYED
# 1          253
# 3          562
# 5          702
# 7          245
# 9          609
# 11         714
# 13         351
# 15         878
# 17         906
# 19         290
# 21         720
# 23         861

# %%
#Data set for women is defined
Merged_data_women = Merged_data[Merged_data["SEX"]=="Women"]
Merged_data_women
# Out:
#                         EDUCATION LEVEL    SEX  YEAR  EDUCATED      STATUS  \
# 0      H40 Short cycle higher education  Women  2018      9573  Unemployed
# 2   H50 Vocational bachelors educations  Women  2018     41903  Unemployed
# 4                  H70 Masters programs  Women  2018     31463  Unemployed
# 6      H40 Short cycle higher education  Women  2019      9281  Unemployed
# 8   H50 Vocational bachelors educations  Women  2019     41552  Unemployed
# 10                 H70 Masters programs  Women  2019     32964  Unemployed
# 12     H40 Short cycle higher education  Women  2020      9129  Unemployed
# 14  H50 Vocational bachelors educations  Women  2020     41729  Unemployed
# 16                 H70 Masters programs  Women  2020     34186  Unemployed
# 18     H40 Short cycle higher education  Women  2021      9148  Unemployed
# 20  H50 Vocational bachelors educations  Women  2021     42664  Unemployed
# 22                 H70 Masters programs  Women  2021     36036  Unemployed
#
#     UNEMPLOYED
# 0          326
# 2         1063
# 4         1096
# 6          340
# 8         1098
# 10        1135
# 12         433
# 14        1428
# 16        1490
# 18         342
# 20        1252
# 22        1310

# %%
#Use our py file to make a interactive plot
dp.plot_timeseries([Merged_data_women, Merged_data_men])
# Out:
# interactive(children=(Dropdown(description='EDUCATION LEVEL', options=('H40 Short cycle higher education', 'H5…

# %% [markdown]
# The interactive plot shows that the unemployment for men overall has the same development regardless the education level. Because of the corona pandemic Denmark went through its first shutdown in the beginning of 2020. From all the three interactive plot it is showns that the unemployment icreased in 2020, because of the shutdown. The unemployment for men with short or midlle lenght education increased with around 40 pct. from 2019 to 2020. Where the unemployment for men with a long education increased with around 25 pct. from 2019 to 2020. People with long education often ends in more computerized jobs, which made it easy to work from home in the shutdown. Opposite a shorter education leads to more practical jobs. A lot of companies was forced to shutdown, which had a greater influence of the people with a short or a middle lenght education.

# %% [markdown]
# The same development is shown for the women, where the unemployment is affected by the corona pandemic regrardless of education level. However it is shown from the interactive plots that the unemployment rate is greater the higher education level a woman has. The unemployment increased by around 29 pct. from 2019 to 2020 for women with long education. However the unemployment increased by around 21 pct. from 2019 to 2020 for women with short education. In general more women than men are public employed. A lot of the jobs which demands a shorter education and which is dominated by women are public, such as pedagogues, nurses or social workers. The private sector was probably faster to layoff people than the public sector, which explains this development.
